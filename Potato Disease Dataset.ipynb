# %% [markdown]
# # Intorduction

# %%
# Setup
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
# Avoid OMM Error
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# check the GPU
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# define the images directory
data_dir = "/kaggle/input/potato-disease-leaf-datasetpld/PLD_3_Classes_256"
print(os.listdir(data_dir))
# Out:
# ['Validation', 'Training', 'Testing']

# %%
# let`s make EDA for the dataset
data_splits = os.listdir(data_dir)
for data_kind in data_splits:
    classes = os.listdir(os.path.join(data_dir,data_kind))
    print(f'*We Process the {data_kind}')
    for class_ in classes:
        path = os.path.join(os.path.join(data_dir,data_kind),class_)
        print(f'  we have a {len(os.listdir(path))} images from class {class_}')
    print('')
# Out:
# *We Process the Validation
#   we have a 151 images from class Late_Blight
#   we have a 163 images from class Early_Blight
#   we have a 102 images from class Healthy
#
# *We Process the Training
#   we have a 1132 images from class Late_Blight
#   we have a 1303 images from class Early_Blight
#   we have a 816 images from class Healthy
#
# *We Process the Testing
#   we have a 141 images from class Late_Blight
#   we have a 162 images from class Early_Blight
#   we have a 102 images from class Healthy

# %%
# Filter out Corrupted images

num_skipped = 0
data_splits = os.listdir(data_dir)

for data_kind in data_splits:
    data_kind_path = os.path.join(data_dir,data_kind)
    print(f'*We Process the {data_kind}')
    
    classes = os.listdir(data_kind_path)
    for class_ in classes:
        folder_path = os.path.join(data_kind_path,class_)
        for fname in os.listdir(folder_path):
            fpath = os.path.join(folder_path,fname)

            try:
                fobj = open(fpath,"rb")
                is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
            finally:
                fobj.close()

            if not is_jfif:
                num_skipped += 1
                os.remove(fpath)
    print(f"  Deleted {num_skipped} Images for {data_kind}\n")
# Out:
# *We Process the Validation
#   Deleted 0 Images for Validation
#
# *We Process the Training
#   Deleted 0 Images for Training
#
# *We Process the Testing
#   Deleted 0 Images for Testing

# %% [markdown]
# # Genrate a Dataset and Visualize

# %%
# load data with tf.utils.image_dataset_from_directory
IMAGE_SIZE = (256,256)
BATCH_SIZE = 16
SEED = 42

# make train-testing-validation datasets
def load_data(data_dir):
    data = []
    for class_d in os.listdir(data_dir):
        data.append(
            tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir,class_d),
            image_size = IMAGE_SIZE,
            batch_size = BATCH_SIZE,
            seed = SEED)
                   )
    return data
# apllying the Load dataset
test_ds, train_ds, val_ds = load_data(data_dir)
# Out:
# Found 416 files belonging to 3 classes.
# Found 3251 files belonging to 3 classes.
# Found 405 files belonging to 3 classes.

# %%
# plot Visualize 
plt.figure(figsize=(10,10))
for image, label in test_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(train_ds.class_names[label[i]])
        plt.axis("off");

# %% [markdown]
# ## Standardize the data

# %%
# standardize values to be in the [0,1] range
normalization_layer = tf.keras.layers.Rescaling(1./255)

# using thr Dataset.map to apply this layer
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# check pixels after normalization
images_batch, label_batch = next(iter(normalized_ds))
random_image = images_batch[4]
print(f' min value = {np.min(random_image)} , max value =  {np.max(random_image)}')
# Out:
#  min value = 0.0 , max value =  1.0

# %% [markdown]
# # Configure the dataset for performance

# %%
# make sure to use buffered prefetching , yield the data without having I/O become bloking
def Configure(dataset):
    dataset = dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

# apply the function
train_ds = Configure(train_ds)
val_ds = Configure(val_ds)

# %% [markdown]
# # Build a Model

# %%
# build a small version of the `Xception Network`

NUM_CLASSES = 3
INPUT_SHAPE = IMAGE_SIZE +(3,)
model = tf.keras.Sequential([
    
    # rescaling and Data augmentation block
    tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=INPUT_SHAPE),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.Rescaling(1.0/255),
    
    # Conv2D Block
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    # Flatten Block
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    
],name = "Mido")


# plot the model
keras.utils.plot_model(model, show_shapes=True)

# %%
# Compile the Model  
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy'])

# %%
# Define Callback
class CustomCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('val_accuracy')>=0.98):   
            keys = list(logs.keys())
            print("End epoch {} of training; got log keys: {}".format(epoch, keys))
            self.model.stop_training = True
            
# define object from CustomCallback Class
callbacks = CustomCallback()

# %%
# training the model
EPOCHS = 50
history = model.fit(
                    train_ds,
                    validation_data=val_ds,
                    epochs =EPOCHS,
                    callbacks=[callbacks])
# Out:
# Epoch 1/50
# 204/204 [==============================] - 13s 25ms/step - loss: 1.0201 - accuracy: 0.4783 - val_loss: 1.0487 - val_accuracy: 0.5210
# Epoch 2/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.8203 - accuracy: 0.6398 - val_loss: 0.7800 - val_accuracy: 0.6938
# Epoch 3/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.6773 - accuracy: 0.7182 - val_loss: 0.5511 - val_accuracy: 0.7975
# Epoch 4/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.5375 - accuracy: 0.8038 - val_loss: 0.6345 - val_accuracy: 0.7951
# Epoch 5/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.4341 - accuracy: 0.8404 - val_loss: 0.4516 - val_accuracy: 0.8568
# Epoch 6/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.3349 - accuracy: 0.8800 - val_loss: 0.3438 - val_accuracy: 0.8864
# Epoch 7/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.2689 - accuracy: 0.8973 - val_loss: 0.2739 - val_accuracy: 0.9136
# Epoch 8/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.2291 - accuracy: 0.9169 - val_loss: 0.3829 - val_accuracy: 0.8914
# Epoch 9/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.2054 - accuracy: 0.9253 - val_loss: 0.4663 - val_accuracy: 0.8593
# Epoch 10/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1738 - accuracy: 0.9422 - val_loss: 0.1990 - val_accuracy: 0.9556
# Epoch 11/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1601 - accuracy: 0.9440 - val_loss: 0.1973 - val_accuracy: 0.9457
# Epoch 12/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1295 - accuracy: 0.9569 - val_loss: 0.1695 - val_accuracy: 0.9580
# Epoch 13/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1322 - accuracy: 0.9536 - val_loss: 0.2336 - val_accuracy: 0.9432
# Epoch 14/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1445 - accuracy: 0.9477 - val_loss: 0.3754 - val_accuracy: 0.9062
# Epoch 15/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1103 - accuracy: 0.9640 - val_loss: 0.3414 - val_accuracy: 0.8988
# Epoch 16/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1234 - accuracy: 0.9582 - val_loss: 0.2128 - val_accuracy: 0.9481
# Epoch 17/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1256 - accuracy: 0.9557 - val_loss: 0.1869 - val_accuracy: 0.9556
# Epoch 18/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0970 - accuracy: 0.9677 - val_loss: 0.2168 - val_accuracy: 0.9531
# Epoch 19/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1149 - accuracy: 0.9649 - val_loss: 0.1578 - val_accuracy: 0.9605
# Epoch 20/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0981 - accuracy: 0.9655 - val_loss: 0.1849 - val_accuracy: 0.9556
# Epoch 21/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0952 - accuracy: 0.9677 - val_loss: 0.1902 - val_accuracy: 0.9506
# Epoch 22/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1026 - accuracy: 0.9674 - val_loss: 0.1530 - val_accuracy: 0.9630
# Epoch 23/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1100 - accuracy: 0.9659 - val_loss: 0.2041 - val_accuracy: 0.9679
# Epoch 24/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0818 - accuracy: 0.9766 - val_loss: 0.2301 - val_accuracy: 0.9605
# Epoch 25/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0886 - accuracy: 0.9714 - val_loss: 0.3014 - val_accuracy: 0.9556
# Epoch 26/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.1075 - accuracy: 0.9671 - val_loss: 0.2796 - val_accuracy: 0.9407
# Epoch 27/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0848 - accuracy: 0.9754 - val_loss: 0.1155 - val_accuracy: 0.9630
# Epoch 28/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0806 - accuracy: 0.9742 - val_loss: 0.1472 - val_accuracy: 0.9605
# Epoch 29/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0796 - accuracy: 0.9745 - val_loss: 0.1887 - val_accuracy: 0.9605
# Epoch 30/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0687 - accuracy: 0.9785 - val_loss: 0.1326 - val_accuracy: 0.9728
# Epoch 31/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0698 - accuracy: 0.9791 - val_loss: 0.1352 - val_accuracy: 0.9679
# Epoch 32/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0957 - accuracy: 0.9695 - val_loss: 0.1014 - val_accuracy: 0.9704
# Epoch 33/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0673 - accuracy: 0.9782 - val_loss: 0.0855 - val_accuracy: 0.9654
# Epoch 34/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0777 - accuracy: 0.9735 - val_loss: 0.1612 - val_accuracy: 0.9630
# Epoch 35/50
# 204/204 [==============================] - 4s 20ms/step - loss: 0.0605 - accuracy: 0.9800 - val_loss: 0.1287 - val_accuracy: 0.9654
# Epoch 36/50
# 204/204 [==============================] - 4s 22ms/step - loss: 0.0730 - accuracy: 0.9739 - val_loss: 0.1563 - val_accuracy: 0.9704
# Epoch 37/50
# 204/204 [==============================] - 4s 20ms/step - loss: 0.0686 - accuracy: 0.9748 - val_loss: 0.1240 - val_accuracy: 0.9728
# Epoch 38/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0663 - accuracy: 0.9785 - val_loss: 0.2012 - val_accuracy: 0.9580
# Epoch 39/50
# 204/204 [==============================] - 4s 20ms/step - loss: 0.0637 - accuracy: 0.9812 - val_loss: 0.2091 - val_accuracy: 0.9630
# Epoch 40/50
# 204/204 [==============================] - 4s 21ms/step - loss: 0.0618 - accuracy: 0.9788 - val_loss: 0.2060 - val_accuracy: 0.9802
# End epoch 39 of training; got log keys: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# # Model Evaluation

# %%
# list all data in history
print(history.history.keys())
print("")
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')

# summarize history for loss
plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evalute model
model.evaluate(test_ds)
# Out:
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.9808
# [0.05269317328929901, 0.9807692170143127]

# %%
# To Color The Output
from termcolor import colored

# %%
# ok everythink look nice, let`s check pic manually
for image_batch, label_batch in test_ds.take(1):
    idx = np.random.randint(0,15)
    print(f"The Real Image was: ",colored({test_ds.class_names[label[idx]]}, 'red'),"\n")
    plt.imshow(image_batch[idx].numpy().astype('uint8'))
    plt.title(test_ds.class_names[label[idx]])
    plt.axis("off");
    plt.show()
    
    print(f"\nThe Model Prediction was: \n")
    print(image_batch.shape)
    pred = model.predict(image_batch)
    pred_idx = np.argmax(pred[idx])
    confidence = str(round(100*(np.max(pred[idx])), 2)) + " %"
    print("")
    print("Class From Model Prediction is :",colored({test_ds.class_names[label[pred_idx]]}, 'green')," with confidence =",colored({confidence},'yellow'))
# Out:
# The Real Image was:  {'Early_Blight'}
# The Model Prediction was:
#
# (16, 256, 256, 3)
#
# Class From Model Prediction is : {'Early_Blight'}  with confidence = {'100.0 %'}

# %%
# saving the model
model.save('save_model')

# %% [markdown]
# # Convert to ONNX

# %%
# # Convert to ONNX using the Python API
# !pip install tf2onnx onnxruntime
# import tf2onnx
# import onnxruntime as rt

# spec = (tf.TensorSpec((None, 256, 256, 3), tf.float32, name="input"),)
# output_path = model.name + ".onnx"

# model_proto, _ = tf2onnx.convert.from_keras(model, input_signature=spec, opset=13, output_path=output_path)
# output_names = [n.name for n in model_proto.graph.output]

# %%
# # Convert to ONNX using the command line

# !python3 -m tf2onnx.convert --opset 13 \
#     --saved-model {os.path.join("","save_model" )} \
#     --output  {os.path.join("save_model", model.name + ".onnx")}

# %%
path = os.path.join("/save_model", model.name + ".onnx")
print(path)
# Out:
# /save_model/Mido.onnx
